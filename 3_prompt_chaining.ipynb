# %%
#importing the dependencies:
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
import os
from dotenv import load_dotenv

# %%
load_dotenv()
hf_api_key = os.getenv("hf_api_token")

# %%
#importing the model:

llm_model = HuggingFaceEndpoint(
    repo_id="google/gemma-3-27b-it",
    task="text-generation",
    huggingfacehub_api_token=hf_api_key
)

model = ChatHuggingFace(llm=llm_model)

# %%
class blogstate(TypedDict) :
    title:str
    outline: str
    content:str

# %%
def create_outline(state:blogstate) ->blogstate :

    #fetch title:
    title=state['title']

    #call llm generate outline:
    prompt=f"generate a detailed outline of a topic :{title}"
    outline=model.invoke(prompt)

    #update state:
    state['outline']=outline

    return state

# %%
def create_blog(state: blogstate) ->blogstate:
    title=state['title']
    outline=state['outline']

    prompt=f"write a detailed blog on the title: {title} using this outline \n{outline}"

    content=model.invoke(prompt).content

    state['content']=content

    return state

# %%
graph=StateGraph(blogstate)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

#add edges:
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow=graph.compile()

# %%
inital_state={'title':'evolution of human '}
final_state=workflow.invoke(inital_state)
print(final_state)
# Out:
# {'title': 'evolution of human ', 'outline': AIMessage(content="## Evolution of Humans: A Detailed Outline\n\nThis outline covers the evolution of humans, from our earliest ancestors to modern *Homo sapiens*. It's broken down into sections covering geological timescale, key hominin groups, major evolutionary trends, and current research areas.\n\n**I. Introduction: What is Human Evolution? (Setting the Stage - ~5% of content)**\n\n*   **A. Defining Evolution:** Briefly explain the core principles of evolution by natural selection (variation, inheritance, selection, time).\n*   **B. What Makes Humans Unique?**  Highlight key characteristics that differentiate humans from other primates (bipedalism, large brain size, language, culture, tool use).\n*   **C.  The Importance of Studying Human Evolution:**  Understanding our origins, behavior, and potential future.\n*   **D.  Methods Used to Study Human Evolution:**\n    *   **Paleontology:** Fossil discovery and analysis.\n    *   **Primatology:** Studying living primates for insights into our ancestors.\n    *   **Genetics:** Analyzing DNA to determine relationships and timelines.\n    *   **Archaeology:**  Studying material culture (tools, settlements) to understand behavior.\n    *   **Geology & Dating Techniques:** Establishing the age of fossils and sites (radiometric dating, stratigraphy).\n\n\n\n**II. Geological & Environmental Context (Setting the Scene - ~10% of content)**\n\n*   **A. Deep Time & the Cenozoic Era:**  Understanding the relevant geological timescale (66 million years ago to present).\n*   **B.  The Miocene Epoch (23-5.3 mya):**  The critical period for ape and early hominin diversification. \n    *   Climate changes: Cooling and drying trends, expansion of grasslands.\n    *   Geographical changes: Formation of rift valleys in Africa.\n*   **C.  The Pliocene Epoch (5.3-2.6 mya):** Continued drying and grassland expansion, emergence of early hominins.\n*   **D.  The Pleistocene Epoch (2.6 mya – 11,700 years ago):**  Ice Ages, fluctuating climate, and the evolution of *Homo*.\n*   **E.  Environmental Pressures & Evolutionary Drivers:**  How climate change, resource availability, and competition shaped hominin evolution. (e.g., Savanna hypothesis, Aridity hypothesis)\n\n**", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 20, 'total_tokens': 532}, 'model_name': 'google/gemma-3-27b-it', 'system_fingerprint': None, 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019b5a44-38c1-7b70-adef-eb1e25213e36-0', usage_metadata={'input_tokens': 20, 'output_tokens': 512, 'total_tokens': 532}), 'content': '## Evolution of Humans: A Detailed Outline\n\n### I. Introduction: What is Human Evolution? (Setting the Stage)\n\nHuman evolution is arguably the most compelling story in all of science – a narrative of adaptation, innovation, and survival spanning millions of years. It’s a journey from tree-dwelling primates to the globally dominant species we are today. But what *is* human evolution, and why does it matter?\n\n**A. Defining Evolution:** At its core, evolution is the change in the heritable characteristics of biological populations over successive generations. The engine driving this change is **natural selection**, a process built on four key pillars: **variation** (individuals within a population exhibit differences), **inheritance** (traits are passed from parents to offspring), **selection** (individuals with traits better suited to their environment are more likely to survive and reproduce), and **time** (these changes accumulate over vast stretches of time).  Evolution isn\'t a linear progression towards "perfection," but rather a branching bush of adaptation to specific environmental challenges.\n\n**B. What Makes Humans Unique?** While we share a common ancestry with all life on Earth, and particularly with other primates, several characteristics distinguish *Homo sapiens*.  Perhaps the most fundamental  ...

# %%
print(final_state['title'])
# Out:
# evolution of human

# %%
print(final_state['outline'])
# Out:
# content="## Evolution of Humans: A Detailed Outline\n\nThis outline covers the evolution of humans, from our earliest ancestors to modern *Homo sapiens*. It's broken down into sections covering geological timescale, key hominin groups, major evolutionary trends, and current research areas.\n\n**I. Introduction: What is Human Evolution? (Setting the Stage - ~5% of content)**\n\n*   **A. Defining Evolution:** Briefly explain the core principles of evolution by natural selection (variation, inheritance, selection, time).\n*   **B. What Makes Humans Unique?**  Highlight key characteristics that differentiate humans from other primates (bipedalism, large brain size, language, culture, tool use).\n*   **C.  The Importance of Studying Human Evolution:**  Understanding our origins, behavior, and potential future.\n*   **D.  Methods Used to Study Human Evolution:**\n    *   **Paleontology:** Fossil discovery and analysis.\n    *   **Primatology:** Studying living primates for insights into our ancestors.\n    *   **Genetics:** Analyzing DNA to determine relationships and timelines.\n    *   **Archaeology:**  Studying material culture (tools, settlements) to understand behavior.\n    *   **Geology & Dating Techniques:** Establishing the age of fossils and sites (radiometric dating, stratigraphy).\n\n\n\n**II. Geological & Environmental Context (Setting the Scene - ~10% of content)**\n\n*   **A. Deep Time & the Cenozoic Era:**  Understanding the relevant geological timescale (66 million years ago to present).\n*   **B.  The Miocene Epoch (23-5.3 mya):**  The critical period for ape and early hominin diversification. \n    *   Climate changes: Cooling and drying trends, expansion of grasslands.\n    *   Geographical changes: Formation of rift valleys in Africa.\n*   **C.  The Pliocene Epoch (5.3-2.6 mya):** Continued drying and grassland expansion, emergence of early hominins.\n*   **D.  The Pleistocene Epoch (2.6 mya – 11,700 years ago):**  Ice Ages, fluctuating climate, and the evolution of *Homo*.\n*   **E.  Environmental Pressures & Evolutionary Drivers:**  How climate change, resource availability, and competition shaped hominin evolution. (e.g., Savanna hypothesis, Aridity hypothesis)\n\n**" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 20, 'total_tokens': 532}, 'model_name': 'google/gemma-3-27b-it', 'system_fingerprint': None, 'finish_reason': 'length', 'logprobs': None} id='lc_run--019b5a44-38c1-7b70-adef-eb1e25213e36-0' usage_metadata={'input_tokens': 20, 'output_tokens': 512, 'total_tokens': 532}

# %%
final_state['content']
# Out:
# '## Evolution of Humans: A Detailed Outline\n\n### I. Introduction: What is Human Evolution? (Setting the Stage)\n\nHuman evolution is arguably the most compelling story in all of science – a narrative of adaptation, innovation, and survival spanning millions of years. It’s a journey from tree-dwelling primates to the globally dominant species we are today. But what *is* human evolution, and why does it matter?\n\n**A. Defining Evolution:** At its core, evolution is the change in the heritable characteristics of biological populations over successive generations. The engine driving this change is **natural selection**, a process built on four key pillars: **variation** (individuals within a population exhibit differences), **inheritance** (traits are passed from parents to offspring), **selection** (individuals with traits better suited to their environment are more likely to survive and reproduce), and **time** (these changes accumulate over vast stretches of time).  Evolution isn\'t a linear progression towards "perfection," but rather a branching bush of adaptation to specific environmental challenges.\n\n**B. What Makes Humans Unique?** While we share a common ancestry with all life on Earth, and particularly with other primates, several characteristics distinguish *Homo sapiens*.  Perhaps the most fundamental is **bipedalism** – the ability to walk upright on two legs. This freed our hands for tool use, another defining trait.  Coupled with bipedalism came an increase in **brain size**, enabling complex thought, problem-solving, and ultimately, **language**.  Beyond biology, **culture** – the transmission of learned behaviors and knowledge – and sophisticated **tool use** set us apart. These aren’t isolated traits, but interconnected adaptations that built on each other.\n\n**C. The Importance of Studying Human Evolution:** Understanding our evolutionary history isn’t just about filling in the gaps of the past. It provides crucial insights into our present behavior, vulnerabilities, and potential future.  By studying our ancestors, we can gain a better understanding of the origins of disease, the development of social structures, and even the roots of our cognitive abilities. It also fosters a greater appreciation for the interconnectedness of life and our place within the natural world.\n\n**D. Methods Used to Study Human Evolution:** Unraveling the story of human evolution is a multidisciplinary endeavor. \n\n*   **Paleontology:** This is the cornerstone of our understanding, involving the discovery and analysis of **fossils** – the preserved remains or traces of ancient organisms.  F'
